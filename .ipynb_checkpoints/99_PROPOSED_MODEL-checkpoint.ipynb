# %%
######################################################## CONSTANTS ########################################################
import CONSTANTS as c

NR_OF_BINS = c.NR_OF_BINS
INTERPLOATION_POINTS = c.INTERPLOATION_POINTS
FFT_AC_COEFFICIENT  = c.FFT_AC_COEFFICIENT
LOWER_POINT = c.LOWER_POINT
UPPER_POINT = c.UPPER_POINT
THRESHOLD = c.THRESHOLD
PREPROCESSED_DATA_PATH = c.PREPROCESSED_DATA_PATH
FEATURE_ENGINEERED_DATA_PATH = c.FEATURE_ENGINEERED_DATA_PATH

######################################################## LIBRARIES ########################################################
import pandas as pd

import numpy as np

from sklearn.preprocessing import MinMaxScaler

import os

i = 0
for oFile in os.walk(PREPROCESSED_DATA_PATH):
    sFolderPath = oFile[0]
    
    if sFolderPath != PREPROCESSED_DATA_PATH:
        sSubFolder = sFolderPath.split('\\')[-1]
        
        sFolderToWrite = r'{}\{}'.format(FEATURE_ENGINEERED_DATA_PATH, sSubFolder)
        
        if os.path.exists(sFolderToWrite) == False:
            os.makedirs(sFolderToWrite)
        
        if all(elem in os.listdir(sFolderToWrite)  for elem in  ['X_ORIGINAL.npy', 'X_ORIGINAL.npy', 'X_ORIGINAL.npy']) == True:
            continue

            
        ######################################################## DATA SOURCE ########################################################
        X_ORIGINAL = np.load(r'{}\X_ORIGINAL.npy'.format(sFolderPath))
        X_TIME_ORIGINAL = np.load(r'{}\X_TIME_ORIGINAL.npy'.format(sFolderPath))
        Y_ORIGINAL = np.load(r'{}\Y_ORIGINAL.npy'.format(sFolderPath))
        
        
        if i ==0:
            X = X_ORIGINAL
            Y = Y_ORIGINAL
            X_TIME = X_TIME_ORIGINAL
        else:
            X = np.concatenate([X, X_ORIGINAL])
            X_TIME = np.concatenate([X_TIME, X_TIME_ORIGINAL])
            Y = np.concatenate([Y, Y_ORIGINAL])            
        
        i = i +1
        
        if i == 3:
            break


X = X[:,:,:,0]
Y = Y[:,:,:,0]
            
######################################################## PREPROCESSING ########################################################


# remove outliers
X[X>UPPER_POINT] = UPPER_POINT
X[X<LOWER_POINT] = LOWER_POINT

Y[Y>UPPER_POINT] = UPPER_POINT
Y[Y<LOWER_POINT] = LOWER_POINT


# XTIME consists of minute, hour, day of week, day of month, month, year
# exclude month and year.
X_TIME = X_TIME[:, :4]

# convert cyclic features to time sinus function
X_TIME = (2 * np.pi * X_TIME)/X_TIME.max(axis = 0)
X_TIME = np.sin(X_TIME)


# scale between 0 and 1
oScaler_X_time = MinMaxScaler()
X_TIME = oScaler_X_time.fit_transform(X_TIME) 

oScaler_X_term = MinMaxScaler()
X = oScaler_X_term.fit_transform(X.reshape(-1, 1)).reshape(X.shape)

oScaler_Y_term = MinMaxScaler()
Y = oScaler_Y_term.fit_transform(Y.reshape(-1, 1)).reshape(Y.shape)

# %%
######################################################## EXPLORATORY DATA ANALYSIS ########################################################
import matplotlib.pyplot as plt
iIndex = 111

plt.plot(range(0, 60), X[iIndex, 0,:])
plt.plot(range(60, 120), X[iIndex, 1,:])
plt.plot(range(120, 180), X[iIndex, 2,:])
plt.plot(range(180, 240), X[iIndex, 3,:])
plt.plot(range(240, 300), Y[iIndex, 0,:])
plt.show()

# %%
######################################################## MODEL ########################################################
import tensorflow as tf


class Block(tf.Module):
    
    def __init__(self, 
                 p_aHiddenArchitecture: list, 
                 p_iFftAcCoeff: int,
                 p_aBinBoundaries: list,
                 p_iNrOfIntervals: int
                ): 
        super(Block, self).__init__()
        self.iFftAcCoeff = p_iFftAcCoeff
        self.aBinBoundaries = p_aBinBoundaries
        self.iNrOfIntervals = p_iNrOfIntervals
        
        # mlp stack definition
        aLayers = [tf.keras.layers.Flatten()]
        for iHiddenSize in p_aHiddenArchitecture:
            aLayers = aLayers + [
                tf.keras.layers.Dense(iHiddenSize), 
                tf.keras.layers.ReLU()
            ]
            
        self.MlpStack = tf.keras.Sequential(aLayers)    
    
    
    
    # x: should be in format of nr_of_samples, nr_of_time_steps, nr_of_features
    # note: time step and interval are different things.
    def __call__(self, x):
        
        x = tf.reshape(x, (x.shape[0], self.iNrOfIntervals, -1))
        

        xBinDistByTimeInterval = []
        xShapeByTimeInterval = []
        for i in range(self.iNrOfIntervals):
            # distribution of bins by each time interval
            xInTimeInterval = x[:, i, :]
            xToAdd = tf.keras.layers.Discretization(
                    bin_boundaries = self.aBinBoundaries,
                    output_mode = 'count'
                )(xInTimeInterval)
            xBinDistByTimeInterval.append (xToAdd)
            
            # shape of signal by each time interval (dimension reduction purpose)
            xInTimeInterval = tf.cast(xInTimeInterval, dtype=tf.complex64)
            
            xToAdd = tf.signal.fft(xInTimeInterval)
            xToAdd = xToAdd[:, :self.iFftAcCoeff]
            xToAdd = tf.reshape(xToAdd, (xToAdd.shape[0], -1)) # type of this data is complex number.
            
            xShapeByTimeInterval.append(xToAdd)
            
        
        xBinDistByTimeInterval = tf.stack(xBinDistByTimeInterval, axis = 1)
        xBinDistByTimeInterval = tf.divide(xBinDistByTimeInterval, tf.expand_dims(tf.reduce_sum(xBinDistByTimeInterval, axis = 2), axis =2)) #normalization between 0 and 1.
        
        xShapeByTimeInterval = tf.stack(xShapeByTimeInterval, axis = 1)
        
        # distribution of time intervals by each bin
        xTimeIntevalDistByBin =  tf.keras.layers.Permute(dims= (2,1))(xBinDistByTimeInterval)
        
        
        
        
        
        # x = self.MlpStack(x)
        return xBinDistByTimeInterval, xShapeByTimeInterval, xTimeIntevalDistByBin
        

BIN_BOUNDARIES = [0.10, 0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90]
NR_OF_INTERVAL = 4
HIDDEN_ARCHITECTURE = [1,3,15]

oBlock = Block(
    p_aHiddenArchitecture =HIDDEN_ARCHITECTURE ,
    p_iFftAcCoeff = FFT_AC_COEFFICIENT,
    p_aBinBoundaries = BIN_BOUNDARIES,
    p_iNrOfIntervals= NR_OF_INTERVAL
)

# %%
x = X[0:2].reshape(-1, 240)

y, z, t   = oBlock(x)
