# %% [markdown]
# # DESIGN OF EXPERIMENTS

# %%
import pandas as pd
import numpy as np
from doepy import build

# %%
sOutputSymbol = 'BTCUSD'
sModelType = 'MLP'

# %%
dfCciDesign = build.central_composite(
    {
        'iBatchSize':[32, 256],
        'iNrOfHiddenNeurons':[50, 250],
        'iBackwardTimeWindow':[2, 8],
        'iForwardTimeWindow':[2, 8]
    },
    face='cci'
)
dfCciDesign = dfCciDesign.astype(np.int)
dfCciDesign.to_csv('Data\Cci Design_'+ sOutputSymbol +'_'+ sModelType +'.csv')

# %%
dfCciDesign
# Out:
#     iBatchSize  iNrOfHiddenNeurons  iBackwardTimeWindow  iForwardTimeWindow
# 0           90                 102                    3                   3
# 1          197                 102                    3                   3
# 2           90                 197                    3                   3
# 3          197                 197                    3                   3
# 4           90                 102                    6                   3
# 5          197                 102                    6                   3
# 6           90                 197                    6                   3
# 7          197                 197                    6                   3
# 8           90                 102                    3                   6
# 9          197                 102                    3                   6
# 10          90                 197                    3                   6
# 11         197                 197                    3                   6
# 12          90                 102                    6                   6
# 13         197                 102                    6                   6
# 14          90                 197                    6                   6
# 15         197                 197                    6                   6
# 16         144                 150                    5                   5
# 17         144                 150                    5                   5
# 18          32                 150                    5                   5
# 19         256                 150                    5                   5
# 20         144                  50                    5                   5
# 21         144                 250                    5                   5
# 22         144                 150                    2                   5
# 23         144                 150                    8                   5
# 24         144                 150                    5                   2
# 25         144                 150                    5                   8
# 26         144                 150                    5                   5
# 27         144                 150                    5                   5
